# %%
import torch
# Out:
# c:\projects\experimental\ai-ml\pytorch-exps\.venv\Lib\site-packages\torch\_subclasses\functional_tensor.py:362: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))

# %%
t1 = torch.tensor([1, 2, 3])
print(t1)
# Out:
# tensor([1, 2, 3])

# %%
t1 = torch.rand([3, 8])
print(t1)
# Out:
# tensor([[0.9962, 0.2902, 0.8653, 0.2430, 0.3571, 0.3428, 0.4343, 0.8821],
#         [0.8082, 0.2760, 0.3758, 0.5623, 0.3129, 0.8412, 0.0955, 0.5257],
#         [0.2688, 0.0882, 0.7747, 0.0912, 0.6413, 0.1692, 0.9630, 0.3887]])

# %%
print(torch.unsqueeze(t1, dim=1).shape)
# Out:
# torch.Size([3, 8, 1])
