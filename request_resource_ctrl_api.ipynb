# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
print(str(r.content))
# Out:
# b'[{"id":"42383163838","type":"PullRequestReviewEvent","actor":{"id":44917347,"login":"mohitb35","display_login":"mohitb35","gravatar_id":"","url":"https://api.github.com/users/mohitb35","avatar_url":"https://avatars.githubusercontent.com/u/44917347?"},"repo":{"id":271585674,"name":"Plant-for-the-Planet-org/planet-webapp","url":"https://api.github.com/repos/Plant-for-the-Planet-org/planet-webapp"},"payload":{"action":"created","review":{"id":2336425073,"node_id":"PRR_kwDOEDARis6LQwRx","user":{"login":"mohitb35","id":44917347,"node_id":"MDQ6VXNlcjQ0OTE3MzQ3","avatar_url":"https://avatars.githubusercontent.com/u/44917347?v=4","gravatar_id":"","url":"https://api.github.com/users/mohitb35","html_url":"https://github.com/mohitb35","followers_url":"https://api.github.com/users/mohitb35/followers","following_url":"https://api.github.com/users/mohitb35/following{/other_user}","gists_url":"https://api.github.com/users/mohitb35/gists{/gist_id}","starred_url":"https://api.github.com/users/mohit
# ...

# %%
test_user_id = "334c65a5-1495-453a-a6de-4d384a781000"
base_url = "http://127.0.0.1:5004/svc/alloc/v1alpha1/resources/users/"
user_url = base_url + test_user_id
headers = { "Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6ImQzMzY2NzdmODZiOWQyNmUzZGUyNWY3NGRiNDcwYzY1NTVjNjkxNGUifQ.....eKZtBQLHGaKTpcBJYOwzdMQ4aA6DWSaBSmsTgcCe3fO23fvTIr-pK4OnbhNv0Zbc5M4QswYZoSk9GdCfJq1xhf9vqEZ5a7qj55Ls5tVrVm80a4vllRVir4wjn17Qa6ngZRTSt0-wKpFdVFi5ScSBRB9GQv2LWrcxfsAyvxkwWfeb-koZwTb3TV8TKL4Gg4enZGxAIdbsJooIXTBU7WG24V7Yx-i2O1wsDpJpwDvkUPXY3Ypsfh6k5s-R-PDPpN12pPtNKEuYtgXlzTpAOfk_gaNrtiOfWqtiejfw_Fe1c1N_kdtzGs6FT2QeC_bEJapOTsio5F4MliA59tdmTMecHg"}

# %%
print(user_url)
# Out:
# http://127.0.0.1:5004/svc/alloc/v1alpha1/resources/users/334c65a5-1495-453a-a6de-4d384a781000

# %%
params = {'allocation': '[{"quantity": 1, "resource": "cpu"}, {"quantity": 1572864000, "resource": "memory"}]' }
import json
#obj = [{"quantity": 1, "resource": "cpu"}, {"quantity": 1572864000, "resource": "memory"}]
#json.dumps(obj)
r = requests.get(user_url, params=params, headers=headers)
r.content
# Out:
# b'{"items": [{"resource": "cpu", "unit": "core", "quantity": 117.45118333498637, "period": 21600000.0, "threshold": 240.0, "ok": true}, {"resource": "memory", "unit": "byte", "quantity": 184734738025.0, "period": 21600000.0, "threshold": 644245094400.0, "ok": true}]}\n'

# %%
r_bytes = r.content
byte_str = r_bytes.decode('utf-8')
json_obj = json.loads(byte_str)
json_obj['items'][0]['period']
# Out:
# 21600000.0

# %%
import requests
import json

def get_cpu_resource_period():
    test_user_id = "334c65a5-1495-453a-a6de-4d384a781000"
    base_url = "http://127.0.0.1:5004/svc/alloc/v1alpha1/resources/users/"
    user_url = base_url + test_user_id
    headers = { "Authorization": "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6ImQzMzY2NzdmODZiOWQyNmUzZGUyNWY3NGRiNDcwYzY1NTVjNjkxNGUifQ.....eFxUdkqqF8rIgC4K6Li6YGSn82acNUsHg3YC9-Ovt7IajAxZnluykW7xndXDE96lISWzgDf-da-nx4XQgEPLLIduUW60-TVt7QN86zWL2OUO_uDapD8JtFICmOxf8pbb5oBy4NmRnpLNdeSV0nkM0FaxmKNhV47RFEmaSCjxzL4N14Q43KmzOjJBIa5NYT-WzB3EHfQwMgO6n6Xf0gUW4V_p3H8GzwOcflO59JsQdh9JTADTzFc8-bt7Pv0npfzKO1gc2p9BasEbMF69u3slY22dY-4FvBvmGIEGzpAhcuPfd5lVRyIlT3ROQFB-tdqt4_K-4Rbl8Ot4TgDHes9CMQ"}    
    params = {'allocation': '[{"quantity": 1, "resource": "cpu"}, {"quantity": 1572864000, "resource": "memory"}]' }
    r = requests.get(user_url, params=params, headers=headers)
    r_bytes = r.content
    byte_str = r_bytes.decode('utf-8')
    json_obj = json.loads(byte_str)
    return json_obj['items'][0]['period']

print(get_cpu_resource_period())

# %%
r.content
# Out:
# b'{"items": [{"resource": "cpu", "unit": "core", "quantity": 117.45118333498637, "period": 21600000.0, "threshold": 240.0, "ok": true}, {"resource": "memory", "unit": "byte", "quantity": 184734738025.0, "period": 21600000.0, "threshold": 644245094400.0, "ok": true}]}\n'

# %%
def get_resource_usage(user_id):
    '''
    url: pre signed aws-s3 url
    fname_zip: absolute name of zip file after downloading
    dir_dest: directory in which zip contents are to be moved
    '''
    try:

# Replace with your actual values
        test_user_id = "334c65a5-1495-453a-a6de-4d384a781000"
        base_url = "http://127.0.0.1:5004"
        allocation = [{"quantity": 1, "resource": "cpu"}, {"quantity": 1572864000, "resource": "memory"}]
        authorization_header = "Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6ImQzMzY2NzdmODZiOWQyNmUzZGUyNWY3NGRiNDcwYzY1NTVjNjkxNGUifQ.....rsfgEFru6plFzV9hXCC_bj2xtnN0mDjtpF8W-pcKMkrBNiIJtPMcB-NSm829fFvxxlmPriePTm2M7PO2CucGewHUu-bu1dXPC2o5VS-UIF_cMCYTq001AhCh1eVu_...        
        response = requests.get(base_url, )
        print(response.status_code)
        
        if response.status_code == 200:
            with open(fpath_zip, 'wb') as f:
                f.write(response.content)
                with ZipFile(fpath_zip, 'r') as zip_ref:
                    zip_ref.extractall(dir_dest)
                k_name_workspace_dir = 'workspace'
                dir_workspace = os.path.join(dir_dest, 'workspace')
                files = os.listdir(dir_workspace)
                for file in files:
                    move(os.path.join(dir_workspace, file), os.path.join(dir_dest, file))
                os.rmdir(dir_workspace)
                os.remove(fpath_zip)

            return 0
        else:
            return -1
    except Exception as e:
        print(e)
        return -2
